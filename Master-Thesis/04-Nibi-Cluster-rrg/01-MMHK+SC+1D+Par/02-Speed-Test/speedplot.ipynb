# %% [markdown]
# # Imports

# %%
# Usual stuff
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# Path
from pathlib import Path

# HDF5
import h5py

# RegEx
import re

# %% [markdown]
# # Speed Plot

# %%
# Get the directory where the script is located
current_dir = Path.cwd()

# Get the output directory
current_out = current_dir

# Max value for the threads
ttmax = 192

for filepath in current_out.iterdir():
    if filepath.is_file() and str(filepath.suffix) == ".test":

        # Open the HDF5 file in read mode
        with h5py.File(filepath, "r") as file:
            
            # Read parameters group into numpy arrays
            tt = file["tt_data"][()]
            rr = file["rr_data"][()]

            # Sort the arrays by runtime
            sort_indices = np.argsort(tt)

            # View those arrays in the sorted order
            tt = tt[sort_indices]
            rr = rr[sort_indices]

            # Ignore higher values
            mask = tt <= ttmax
            tt = tt[mask]
            rr = rr[mask]

            # Get the speedup
            ss = rr[0] / rr

            
            plt.plot(tt, ss, label="Data")
            plt.plot(tt, tt, label="Theory")
            plt.xlabel("Number of Threads")
            plt.ylabel("Speedup")
            plt.title(f"Speedup for Test {filepath.name}")
            plt.legend()
            plt.show()

            plt.plot(tt, ss/tt)
            plt.xlabel("Number of Threads")
            plt.ylabel("Speedup per Thread")
            plt.title(f"Speedup for Test {filepath.name}")
            plt.show()
