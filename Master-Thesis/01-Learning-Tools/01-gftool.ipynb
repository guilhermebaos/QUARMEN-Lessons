# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import gftool as gt
# Out:
# c:\Python312\Lib\site-packages\gftool\precision.py:16: UserWarning: No quad precision datatypes available!
# Some functions might be less accurate.
#   warnings.warn("No quad precision datatypes available!\n"

# %% [markdown]
# # Tutorial
#
# We are following the tutorial from [here](https://gftools.readthedocs.io/en/stable/tutorial.html).

# %% [markdown]
# ## Example

# %%
ww = np.linspace(-1.1, 1.1, num=1000)
dos_ww = gt.lattice.bethe.dos(ww, half_bandwidth=1.)
__ = plt.plot(ww, dos_ww)
__ = plt.xlabel(r"$\epsilon$")
plt.show()
